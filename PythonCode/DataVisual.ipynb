# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(r'/2021+historical_data.csv')

# data cleaning
# check na value 
data.info()
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  2100 non-null   object
#  1   year                          2100 non-null   int64
#  2   Ladder score                  2100 non-null   float64
#  3   Logged GDP per capita         2064 non-null   float64
#  4   Social support                2087 non-null   float64
#  5   Healthy life expectancy       2045 non-null   float64
#  6   Freedom to make life choices  2068 non-null   float64
#  7   Generosity                    2011 non-null   float64
#  8   Perceptions of corruption     1990 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 147.8+ KB
# Country name                      0
# year                              0
# Ladder score                      0
# Logged GDP per capita            36
# Social support                   13
# Healthy life expectancy          55
# Freedom to make life choices     32
# Generosity                       89
# Perceptions of corruption       110
# dtype: int64

# %%
# fill in the na value by mean
mean = data["Logged GDP per capita"].mean()
data["Logged GDP per capita"].fillna(mean,inplace = True)

mean = data["Social support"].mean()
data["Social support"].fillna(mean,inplace = True)

mean = data["Healthy life expectancy"].mean()
data["Healthy life expectancy"].fillna(mean,inplace = True)

mean = data["Freedom to make life choices"].mean()
data["Freedom to make life choices"].fillna(mean,inplace = True)

mean = data["Generosity"].mean()
data["Generosity"].fillna(mean,inplace = True)

mean = data["Perceptions of corruption"].mean()
data["Perceptions of corruption"].fillna(mean,inplace = True)

data.isnull().sum()
# Out:
# Country name                    0
# year                            0
# Ladder score                    0
# Logged GDP per capita           0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
data1 = data.iloc[:,[2,3,4,5,6,7,8]]

# %%
data1
# Out:
#       Ladder score  Logged GDP per capita  Social support  \
# 0            7.842                 10.775           0.954
# 1            7.620                 10.933           0.954
# 2            7.571                 11.117           0.942
# 3            7.554                 10.878           0.983
# 4            7.464                 10.932           0.942
# ...            ...                    ...             ...
# 2095         3.616                  8.049           0.775
# 2096         2.694                  7.950           0.759
# 2097         3.160                  7.829           0.717
# 2098         2.694                  7.950           0.759
# 2099         3.160                  7.829           0.717
#
#       Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                        72.0                         0.949      -0.098
# 1                        72.7                         0.946       0.030
# 2                        74.4                         0.919       0.025
# 3                        73.0                         0.955       0.160
# 4                        72.4                         0.913       0.175
# ...                       ...                           ...         ...
# 2095                     55.6                         0.763      -0.068
# 2096                     56.2                         0.632      -0.064
# 2097                     56.8                         0.643      -0.009
# 2098                     56.2                         0.632      -0.064
# 2099                     56.8                         0.643      -0.009
#
#       Perceptions of corruption
# 0                         0.186
# 1                         0.179
# 2                         0.292
# 3                         0.673
# 4                         0.338
# ...                         ...
# 2095                      0.844
# 2096                      0.831
# 2097                      0.789
# 2098                      0.831
# 2099                      0.789
#
# [2100 rows x 7 columns]

# %%
#Data visualization
for col in data1.columns:
    plt.hist(data1[[col]])
    plt.title(col)
    plt.show()

# %%
#correlation matrix
corrMatrix = data1.corr()
print(corrMatrix)
plt.matshow(corrMatrix)
plt.show()
# Out:
#                               Ladder score  Logged GDP per capita  \
# Ladder score                      1.000000               0.784413
# Logged GDP per capita             0.784413               1.000000
# Social support                    0.708183               0.689646
# Healthy life expectancy           0.742321               0.835425
# Freedom to make life choices      0.529309               0.365264
# Generosity                        0.172431              -0.014611
# Perceptions of corruption        -0.419462              -0.334812
#
#                               Social support  Healthy life expectancy  \
# Ladder score                        0.708183                 0.742321
# Logged GDP per capita               0.689646                 0.835425
# Social support                      1.000000                 0.620164
# Healthy life expectancy             0.620164                 1.000000
# Freedom to make life choices        0.411547                 0.389868
# Generosity                          0.053568                 0.007876
# Perceptions of corruption          -0.215423                -0.316466
#
#                               Freedom to make life choices  Generosity  \
# Ladder score                                      0.529309    0.172431
# Logged GDP per capita                             0.365264   -0.014611
# Social support                                    0.411547    0.053568
# Healthy life expectancy                           0.389868    0.007876
# Freedom to make life choices                      1.000000    0.307747
# Generosity                                        0.307747    1.000000
# Perceptions of corruption                        -0.472184   -0.269875
#
#                               Perceptions of corruption
# Ladder score                                  -0.419462
# Logged GDP per capita                         -0.334812
# Social support                                -0.215423
# Healthy life expectancy                       -0.316466
# Freedom to make life choices                  -0.472184
# Generosity                                    -0.269875
# Perceptions of corruption                      1.000000

# %%
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
data1.describe()
# Out:
#        Ladder score  Logged GDP per capita  Social support  \
# count   2100.000000            2100.000000     2100.000000
# mean       5.468979               9.371622        0.812637
# std        1.114936               1.144668        0.117804
# min        2.375000               6.635000        0.290000
# 25%        4.650750               8.480750        0.750000
# 50%        5.391000               9.449000        0.833500
# 75%        6.281500              10.343250        0.905000
# max        8.019000              11.648000        0.987000
#
#        Healthy life expectancy  Freedom to make life choices   Generosity  \
# count              2100.000000                   2100.000000  2100.000000
# mean                 63.471678                      0.745989    -0.001062
# std                   7.369823                      0.139662     0.157869
# min                  32.300000                      0.258000    -0.335000
# 25%                  58.992000                      0.653750    -0.109000
# 50%                  65.100000                      0.763500    -0.017000
# 75%                  68.525000                      0.858000     0.084000
# max                  77.100000                      0.985000     0.698000
#
#        Perceptions of corruption
# count                2100.000000
# mean                    0.745715
# std                     0.181236
# min                     0.035000
# 25%                     0.698000
# 50%                     0.793000
# 75%                     0.866000
# max                     0.983000

# %%
desc = data.describe()

# %%
desc
# Out:
#               year  Ladder score  Logged GDP per capita  Social support  \
# count  2100.000000   2100.000000            2100.000000     2100.000000
# mean   2013.774286      5.468979               9.371622        0.812637
# std       4.487822      1.114936               1.144668        0.117804
# min    2005.000000      2.375000               6.635000        0.290000
# 25%    2010.000000      4.650750               8.480750        0.750000
# 50%    2014.000000      5.391000               9.449000        0.833500
# 75%    2018.000000      6.281500              10.343250        0.905000
# max    2021.000000      8.019000              11.648000        0.987000
#
#        Healthy life expectancy  Freedom to make life choices   Generosity  \
# count              2100.000000                   2100.000000  2100.000000
# mean                 63.471678                      0.745989    -0.001062
# std                   7.369823                      0.139662     0.157869
# min                  32.300000                      0.258000    -0.335000
# 25%                  58.992000                      0.653750    -0.109000
# 50%                  65.100000                      0.763500    -0.017000
# 75%                  68.525000                      0.858000     0.084000
# max                  77.100000                      0.985000     0.698000
#
#        Perceptions of corruption
# count                2100.000000
# mean                    0.745715
# std                     0.181236
# min                     0.035000
# 25%                     0.698000
# 50%                     0.793000
# 75%                     0.866000
# max                     0.983000

# %%
from scipy import stats
import pylab

# %%
x = data1.iloc[:,0]

# %%
stats.normaltest(x)
# Out:
# NormaltestResult(statistic=93.6081253500773, pvalue=4.712526979432738e-21)

# %%
stats.probplot(x, dist="norm", plot=pylab)
pylab.show()

# %%
#Boxplot
fig, ax=plt.subplots(7,1, figsize=(10,15)) 
numeric_col=data1.select_dtypes('float64').columns 
for num_col, axis in zip(numeric_col, ax.ravel()):
    sns.boxplot(x=num_col, data=data1, ax=axis)
plt.tight_layout()
